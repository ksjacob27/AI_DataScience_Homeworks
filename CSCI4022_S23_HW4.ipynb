# %% [markdown]
# <a/ id='top'></a>
#
# # CSCI4022 Homework 4; GMMs
#
# ## Due Monday, March 13 at 11:59 pm to Canvas and Gradescope
#
# #### Submit this file as a .ipynb with *all cells compiled and run* to the associated dropbox.
#
# ***
#
# Your solutions to computational questions should include any specified Python code and results as well as written commentary on your conclusions.  Remember that you are encouraged to discuss the problems with your classmates, but **you must write all code and solutions on your own**.
#
# **NOTES**:
#
# - Any relevant data sets should be available on Canvas. To make life easier on the graders if they need to run your code, do not change the relative path names here. Instead, move the files around on your computer.
# - If you're not familiar with typesetting math directly into Markdown then by all means, do your work on paper first and then typeset it later.  Here is a [reference guide](https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference) linked on Canvas on writing math in Markdown. **All** of your written commentary, justifications and mathematical work should be in Markdown.  I also recommend the [wikibook](https://en.wikibooks.org/wiki/LaTeX) for LaTex.
# - Because you can technically evaluate notebook cells is a non-linear order, it's a good idea to do **Kernel $\rightarrow$ Restart & Run All** as a check before submitting your solutions.  That way if we need to run your code you will know that it will work as expected.
# - It is **bad form** to make your reader interpret numerical output from your code.  If a question asks you to compute some value from the data you should show your code output **AND** write a summary of the results in Markdown directly below your code.
# - 45 points of this assignment are in problems.  The remaining 5 are for neatness, style, and overall exposition of both code and text.
# - This probably goes without saying, but... For any question that asks you to calculate something, you **must show all work and justify your answers to receive credit**. Sparse or nonexistent work will receive sparse or nonexistent credit.
# - There is *not a prescribed API* for these problems.  You may answer coding questions with whatever syntax or object typing you deem fit.  Your evaluation will primarily live in the clarity of how well you present your final results, so don't skip over any interpretations!  Your code should still be commented and readable to ensure you followed the given course algorithm.
# - There are two ways to quickly make a .pdf out of this notebook for Gradescope submission.  Either:
#  - Use File -> Download as PDF via LaTeX.  This will require your system path find a working install of a TeX compiler
#  - Easier: Use File ->  Print Preview, and then Right-Click -> Print using your default browser and "Print to PDF"
#
#
#
# ---
# **Shortcuts:**  [Problem 1](#p1) | [Problem 2](#p2) | [Problem 3](#p3) |
# ---

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm

# %% [markdown]
# ***
# <a/ id='p1'></a>
# [Back to top](#top)
# # Problem 1 (Theory: GMM; 5 pts)
# In the GMM slides, we stated that the weights $w_m$ of the 1-dimensional GMM with pdf
#
# $f(x|\theta)=w_1\phi(x|\mu_1, \sigma_1^2)+w_2\phi(x|\mu_2, \sigma_2^2)+\dots+ w_m\phi(x|\mu_m, \sigma_m^2)$
#
# required the weights to sum to one.
#
# #### a) Use the following markdown cell to prove this statement.  In a sentence, describe how this proof might change in higher dimensions.

# %% [markdown]
# #### b) Is it possible to have a valid pdf $f(x)$ above if any of the weights $w_k$ are negative?  If not, why not?  If so, what other difficulties might be associated with negative weights?

# %% [markdown]
# Yes it is possible that $f(x)$ is a valid PDF as long as the sum of the weights is equals 1 which can still be achieved with negative weights. Negative weights just indicate negative probability which does not have any significant meaning.

# %% [markdown]
# ***
#
# <a/ id='p2'></a>
# [Back to top](#top)
# # Problem 2 (Choose a k? 25 pts)
#
# Continuing with the Pokémon theme of HW3's clustering, we have a data set of geolocated Pokémon Go "spawns" taken from the bay area around San Francisco, CA, US.  What results is a map that should loosely approximate the population density of the San Francisco Bay, with some adjustments according to the weights that Pokémon Go uses (I believe this means more things happen in parks, for example), and some bias due to using cell phone usage as a measure for population location.  The set includes:
#
#
# `lat`: numeric,	Latitude of spawn
#
# `lng`:	numeric,	Longitude
#
# `name`: which Pokémon spawned at each location (you may discard this if desired).
#
# For all prompts, use Euclidean distance ($L_2$).
#
# (**NB**: using Euclidean distance on lat/lon data is not technically correct, you classically have to *project* locations onto a 2D map or find their true great-circle distances apart.  We will ignore this here, as the region is small enough to have only minor error due to ignoring curvature of the surface.)
#
# Here we will focus on the locational problem of latitude versus longitude.  As in kmeans, instead of choosing $k$ we might choose a variety of values of $k$ and implement a GMM for each.
#
# Shown below is the lat/lon locations of the Pokémon.  Not only is there structure, it has a shape: some data appears in lines that aren't perfect circles.  This is a perfect task for the GMM!

# %%
df=pd.read_csv('bayareapokemon.csv', encoding='UTF-8')
print(df.head(3))
plt.scatter(df['lat'], df['lng'])
df=df.drop(columns='name')
# Out:
#          lat         lng     name
# 0  37.361151 -122.014794   Cubone
# 1  37.835080 -122.477904  Spearow
# 2  37.322755 -121.976948  Rattata

# %% [markdown]
# **Part A**:  Write (by hand) a function `GMM(dat, k, init=...)` that performs the EM algorithm for a Gaussian mixture model on a given set of $(X,Y)$ locational data.  You may include random initialization inside the function or as an input.
#
# You should run the algorithm for sufficient steps until convergence, and should return at a minimum, the means, 2x2 covariance matrices, and mixture probabilities of each component.  You may also want to return the responsibilities of each datum to the k components for later use, but this is less necessary.

# %%
def GMM(dat, k):
    ##


    covars = np.zeros((k,2,2))
    means = np.zeros((k,2))
    p_class = np.zeros(k)
    p_class_given_data = np.zeros((len(dat), k))
    pick =np.random.choice(range(len(dat)), size=k, replace=False)
    for i in range(k):
        covars[i,:,:] = np.cov(np.transpose(dat))
        means[i,:]=dat.iloc[pick[i]]
        p_class[i] = 1/k
    cluster =  np.zeros((len(dat), k))
    freq = np.zeros((len(dat), k))
    
    for j in range(50):
        
        for dataNum in range(len(dat)):
            for dim in range(k):
                p_class_given_data[dataNum][dim] = stats.multivariate_normal.pdf(x=(dat.iloc[dataNum]["lat"],dat.iloc[dataNum]["lng"]), mean=means[dim], cov=covars[dim])
                cluster[dataNum][dim] = p_class_given_data[dataNum][dim] * p_class[dim]

        for dataNum in range(len(dat)):
            for dim in range(k):
                p_class_given_data[dataNum][dim] = cluster[dataNum][dim] / sum(cluster[dataNum])
                
                
        dimSum = np.zeros(k)
        for dim in range(k):
            for dataNum in range(len(dat)):
                dimSum[dim] += p_class_given_data[dataNum][dim]
        for dim in range(k):
            p_class[dim] = dimSum[dim] / len(dat)
        for dim in range(k):
            tempMean = np.zeros(2)
            for i in range(2):
                for dataNum in range(len(dat)):
                    tempMean[i] += (1/dimSum[dim]) * p_class_given_data[dataNum][dim] * dat.iloc[dataNum, i]
            means[dim] = tempMean
        for dim in range(k):
            dc = np.zeros((2,2))
            for dataNum in range(len(dat)):
                meanDat = (dat.iloc[dataNum].to_numpy() - means[dim])
                weight = p_class_given_data[dataNum][dim]
                partial = np.outer(meanDat, meanDat)
                weighted = np.multiply(weight, partial)
                dc = np.add(dc, weighted)
            dc = np.multiply((1/dimSum[dim]), dc)
            covars[dim] = dc
    mean_dist_sum = 0
    for dataNum in range(len(dat)):
        for dim in range(k):
            arrMeans = np.square(np.subtract(dat.iloc[dataNum].to_numpy(), means[dim]))
            mean_dist_sum = np.add(mean_dist_sum, np.multiply(p_class_given_data[dataNum][dim], np.sum(arrMeans)))
    
    mean_dist = np.sqrt(np.divide(mean_dist_sum, len(dat)))
          
    
    return p_class_given_data, means, covars, p_class, mean_dist

# %% [markdown]
# **Part B**:
#
# Run your algorithm for $k=[1,2,3,4,5,6,7,8]$, then create an **elbow plot** of the weighted-mean-distance to component for each choice of $k$.
#
# To compute this, take a clustering and its responsibilities $p_{mi}$, then compute the average distance between each point and each cluster, weighted by $p_{mi}$:
#
# $$ \bar{D} = \sqrt{\frac{\sum^n_{i=1}\sum^k_{m=1} p_{mi} (x_i-\mu_m)^2}{n}}$$
#
# (**Idea**: this averages the distance between each point and the 'closest' cluster, but allows for the soft-clustering nature of points to compute distances between multiple clusters.)
#
#
# Create your elbow plot by making a line plot of the values of $\bar{D}$ against $k$.

# %%
kMax = 8

meanLat = np.zeros(kMax)
meanLag = np.zeros(kMax)
x = [i for i in range(1, kMax + 1)]
for k in range(1, kMax + 1):
    dists = GMM(df, k)[4]
    print(f"Calculated mean dists for k = {k}")
    meanLat[k-1] = dists
plt.plot(x, meanLat)
plt.show()
# Out:
# Calculated mean dists for k = 1
# Calculated mean dists for k = 2
# Calculated mean dists for k = 3
# Calculated mean dists for k = 4
# Calculated mean dists for k = 5
# Calculated mean dists for k = 6
# Calculated mean dists for k = 7
# Calculated mean dists for k = 8

# %% [markdown]
# **Part C**:
#
# Based on the plot in part **B**, what looks like the best choice of $k$ for this problem?  Are multiple values in contention?  Explain, and then plot your preferred choice of $k$ where you color each data point according to the cluster with which it has the highest responsibility (i.e. hard cluster based on responsibilities).

# %% [markdown]
# Upon inspection of the plot above, it seems as though k=5 has the best clustering prior to plateauing.

# %%
k = 5

clust = GMM(df, k)[0]
groupNum = np.zeros(len(df))
for i, datFreq in enumerate(clust):
    clusteri = np.argmax(datFreq)
    groupNum[i] = clusteri

scatterGroupings = [[] for i in range(k)]
for i, datum in enumerate(df.to_numpy()):
    scatterGroupings[groupNum[i].astype(int)].append(datum)

for group in scatterGroupings:
    print(group)
    x = []
    y = []
    for datum in group:
        x.append(datum[0])
        y.append(datum[1])

    plt.scatter(x, y)



plt.show()
# Out:
# [array([  37.87584926, -122.2737628 ]), array([  37.64205851, -122.0887598 ]), array([  37.76376836, -122.1875091 ]), array([  37.79083808, -122.2324619 ]), array([  37.87002691, -122.2687119 ]), array([  37.64423403, -122.1005648 ]), array([  37.62959275, -122.0655011 ]), array([  37.60954271, -122.0736688 ]), array([  37.61815918, -122.0377972 ]), array([  37.9305873, -122.2975966]), array([  37.52576967, -121.9860111 ]), array([  37.53900739, -121.989565  ]), array([  37.67397911, -122.1308258 ]), array([  37.74915121, -122.1544253 ]), array([  37.79249407, -122.2407057 ]), array([  37.82509752, -122.2034709 ]), array([  37.70562139, -122.1488364 ]), array([  37.65053238, -122.0326463 ]), array([  37.66523718, -122.0663001 ]), array([  37.76222635, -122.2128694 ]), array([  37.99670908, -122.3155792 ]), array([  37.96104908, -122.3634882 ]), array([  37.88000146, -122.2657875 ]), array([  37.88421598, -122.23716   ]), array([  37.6816532, -122.1058012]), array([  37.86313412, -122.317705  ]), array([  37.86812705, -122.2958248 ]), array([  37.81217696, -122.2304231 ]), array([  37.97379025, -122.3360384 ]), array([  37.82778269, -122.2102982 ]), array([  37.76652461, -122.1977958 ]), array([  37.5894096, -122.0200346]), array([  37.80460732, -122.2449602 ]), array([  37.69165692, -122.1414728 ]), array([  37.67913314, -122.0830787 ]), array([  37.93376571, -122.3240822 ]), array([  37.78371477, -122.2282069 ]), array([  37.61654753, -122.0544914 ]), array([  37.94229313, -122.3602123 ]), array([  37.98506129, -122.3041522 ]), array([  37.81426962, -122.229182  ]), array([  37.79918171, -122.2107415 ]), array([  37.7024495, -122.1248808]), array([  37.67564086, -122.0689636 ]), array([  37.71074685, -122.1646265 ]), array([  37.67858727, -122.0774862 ]), array([  37.82864077, -122.2625972 ]), array([  37.65317815, -122.0917777 ]), array([  37.59326857, -122.0320247 ]), array([  37.88526139, -122.2225332 ]), array([  37.6460865, -122.0836113]), array([  37.61407953, -122.0927541 ]), array([  37.85225817, -122.2272317 ]), array([  37.8281889, -122.2443398]), array([  37.65140463, -122.1160957 ]), array([  37.76862356, -122.2195189 ]), array([  37.74408773, -122.225636  ]), array([  37.76668249, -122.2075496 ]), array([  37.92361443, -122.3329388 ]), array([  37.85811915, -122.2095002 ]), array([  37.64182533, -122.0623936 ]), array([  37.74198257, -122.183607  ]), array([  37.8908104, -122.2679143]), array([  37.92676594, -122.2940529 ]), array([  37.98467891, -122.2724337 ]), array([  37.68088193, -122.0817472 ]), array([  37.88865936, -122.27713   ]), array([  37.77542606, -122.2067516 ]), array([  37.82654986, -122.2099436 ]), array([  37.83576973, -122.26242   ]), array([  37.8801749, -122.241858 ]), array([  37.85674274, -122.2527599 ]), array([  37.60089009, -121.9916973 ]), array([  37.82435656, -122.1983279 ]), array([  37.62735846, -122.0662113 ]), array([  37.79399862, -122.158772  ]), array([  37.59372486, -122.0478318 ]), array([  37.74570628, -122.1203552 ]), array([  37.56347343, -122.0310478 ]), array([  37.81519363, -122.2456693 ]), array([  37.96153011, -122.3370125 ]), array([  37.67587607, -122.1068662 ]), array([  37.85585822, -122.2658761 ]), array([  37.65264684, -122.082191  ]), array([  37.92445205, -122.3449825 ]), array([  37.80911232, -122.2592296 ]), array([  37.74163437, -122.1671101 ]), array([  37.8013423, -122.2227105]), array([  37.92643309, -122.3622487 ]), array([  37.9732594, -122.3445397]), array([  37.75279673, -122.1610784 ]), array([  37.53785376, -122.0018249 ]), array([  37.89870267, -122.2601158 ]), array([  37.72378509, -122.1666666 ]), array([  37.57668696, -122.0524492 ]), array([  37.55228133, -121.9828126 ]), array([  37.59526968, -122.0570664 ]), array([  37.93473927, -122.3574676 ]), array([  37.77363088, -122.1857355 ]), array([  37.83313851, -122.23716   ]), array([  37.55601629, -122.0599076 ]), array([  37.70745894, -122.1310033 ]), array([  37.74878712, -122.1972638 ]), ar ...
# [array([  37.83508033, -122.4779036 ]), array([  37.87976793, -122.5163679 ]), array([  37.7749415, -122.3870363]), array([  37.67976632, -122.3982773 ]), array([  37.75079433, -122.4667595 ]), array([  37.73240074, -122.5020449 ]), array([  37.71346096, -122.4028796 ]), array([  37.71514171, -122.4153578 ]), array([  37.69295615, -122.4201363 ]), array([  37.82728966, -122.4227909 ]), array([  37.77571628, -122.4501297 ]), array([  37.74549724, -122.4334088 ]), array([  37.6827502, -122.4884274]), array([  37.77930568, -122.413057  ]), array([  37.75707148, -122.4504836 ]), array([  37.78181557, -122.4092516 ]), array([  37.68610782, -122.4487143 ]), array([  37.76326269, -122.4753388 ]), array([  37.72912008, -122.4108446 ]), array([  37.78182916, -122.394914  ]), array([  37.7368839, -122.4708281]), array([  37.72574538, -122.4181895 ]), array([  37.78650078, -122.4503951 ]), array([  37.75908053, -122.4267728 ]), array([  37.78302757, -122.4648136 ]), array([  37.76508627, -122.4212867 ]), array([  37.7716281, -122.4317277]), array([  37.7761647, -122.4419023]), array([  37.74920768, -122.4191629 ]), array([  37.83197483, -122.4737468 ]), array([  37.7921205, -122.4642829]), array([  37.75196004, -122.4007555 ]), array([  37.74916927, -122.4316392 ]), array([  37.78834132, -122.4664057 ]), array([  37.79573162, -122.4520759 ]), array([  37.77650083, -122.5130083 ]), array([  37.74419875, -122.5069963 ]), array([  37.78357475, -122.4139419 ]), array([  37.80540588, -122.4276576 ]), array([  37.68583797, -122.3998704 ]), array([  37.86979412, -122.494529  ]), array([  37.67220699, -122.3888951 ]), array([  37.74261859, -122.5084993 ]), array([  37.78529885, -122.4061541 ]), array([  37.71004748, -122.3853545 ]), array([  37.76347456, -122.4386288 ]), array([  37.8825199, -122.4677325]), array([  37.7891756, -122.3976578]), array([  37.76006419, -122.438098  ]), array([  37.82425898, -122.5274182 ]), array([  37.78168906, -122.4166852 ]), array([  37.79431628, -122.4039416 ]), array([  37.75345187, -122.4375671 ]), array([  37.72356919, -122.4538451 ]), array([  37.76165102, -122.4518105 ]), array([  37.79040602, -122.4391597 ]), array([  37.77000609, -122.4701206 ]), array([  37.70863988, -122.4319047 ]), array([  37.75174395, -122.4979775 ]), array([  37.71363677, -122.4280115 ]), array([  37.78587766, -122.4250916 ]), array([  37.657613 , -122.3975692]), array([  37.88605163, -122.5438589 ]), array([  37.7367693, -122.3958876]), array([  37.72795185, -122.4761347 ]), array([  37.85960506, -122.5753188 ]), array([  37.79379162, -122.4513682 ]), array([  37.74439575, -122.4365055 ]), array([  37.7307293, -122.379158 ]), array([  37.73602185, -122.4211097 ]), array([  37.7214997, -122.4905497]), array([  37.65425048, -122.4092516 ]), array([  37.73597377, -122.4108446 ]), array([  37.90079809, -122.5288326 ]), array([  37.83417529, -122.4221715 ]), array([  37.76067749, -122.4474758 ]), array([  37.71223751, -122.3833185 ]), array([  37.8721182, -122.5334291]), array([  37.7055683, -122.4288078]), array([  37.67168051, -122.364108  ]), array([  37.7871135, -122.4142959]), array([  37.88540548, -122.5303353 ]), array([  37.74268127, -122.4134994 ]), array([  37.69698097, -122.4838289 ]), array([  37.78184759, -122.4273037 ]), array([  37.8867782, -122.5316612]), array([  37.91095816, -122.4882505 ]), array([  37.72160396, -122.4263303 ]), array([  37.72353762, -122.4059771 ]), array([  37.70210957, -122.4705628 ]), array([  37.73492587, -122.4203133 ]), array([  37.78418877, -122.4424331 ]), array([  37.77897136, -122.3959761 ]), array([  37.74221603, -122.4271267 ]), array([  37.84793826, -122.5448311 ]), array([  37.75965618, -122.4265958 ]), array([  37.71935523, -122.4508374 ]), array([  37.72330172, -122.5062005 ]), array([  37.87356109, -122.5143345 ]), array([  37.8098077, -122.4099596]), array([  37.77439422, -122.3861511 ])]
# [array([  37.36115129, -122.0147941 ]), array([  37.32275547, -121.9769483 ]), array([  37.50167125, -121.927178  ]), array([  37.31192946, -121.9359783 ]), array([  37.43091773, -121.9661074 ]), array([  37.33226156, -121.8877903 ]), array([  37.30983421, -121.8567503 ]), array([  37.40376383, -122.0133729 ]), array([  37.31263089, -121.9533991 ]), array([  37.30994439, -122.0075102 ]), array([  37.51345904, -121.9686844 ]), array([  37.35149338, -122.0057336 ]), array([  37.37232895, -121.9115313 ]), array([  37.2969224, -121.9798805]), array([  37.32436486, -121.9328672 ]), array([  37.42630949, -122.0361099 ]), array([  37.65131841, -121.9051297 ]), array([  37.30547009, -122.0031574 ]), array([  37.34771996, -121.865823  ]), array([  37.30789088, -121.9321561 ]), array([  37.31498422, -121.9548211 ]), array([  37.32405115, -121.9051297 ]), array([  37.36317607, -122.0274952 ]), array([  37.3918963, -122.0163929]), array([  37.38587369, -121.8901913 ]), array([  37.40091038, -121.9705505 ]), array([  37.41865079, -121.9602422 ]), array([  37.40905157, -121.9649522 ]), array([  37.40212776, -121.9230888 ]), array([  37.33327005, -121.8929479 ]), array([  37.41754641, -121.8860117 ]), array([  37.36480148, -121.9163322 ]), array([  37.45561263, -121.9014842 ]), array([  37.35225752, -121.8917919 ]), array([  37.56529789, -121.9654853 ]), array([  37.34337693, -121.9101088 ]), array([  37.36036638, -121.9974719 ]), array([  37.37643878, -121.9677958 ]), array([  37.31654938, -121.8456307 ]), array([  37.29201642, -121.8788082 ]), array([  37.37232666, -121.9262891 ]), array([  37.36029192, -121.9987157 ]), array([  37.29610412, -122.044191  ]), array([  37.35002695, -121.9599756 ]), array([  37.29948351, -121.9368672 ]), array([  37.6353384, -121.9032625]), array([  37.46256444, -121.9604199 ]), array([  37.43297093, -122.052538  ]), array([  37.37041544, -121.9254001 ]), array([  37.50620688, -121.9947179 ]), array([  37.65270682, -121.8773853 ]), array([  37.2999468, -122.0244755]), array([  37.30877338, -121.8670683 ]), array([  37.52284951, -122.0385965 ]), array([  37.40502019, -121.9765929 ]), array([  37.36848593, -122.0096421 ]), array([  37.30061569, -121.9661074 ]), array([  37.34547715, -122.0239426 ]), array([  37.36065609, -122.0296268 ]), array([  37.5025481, -121.9459334]), array([  37.55401667, -121.9591758 ]), array([  37.32963562, -121.982546  ]), array([  37.4613494, -121.8971272]), array([  37.54887694, -121.9503773 ]), array([  37.29777382, -122.0458782 ]), array([  37.32664371, -122.0154158 ]), array([  37.4149816, -121.8637773]), array([  37.36135108, -121.8574619 ]), array([  37.63758265, -121.8898356 ]), array([  37.48666597, -121.9237111 ]), array([  37.44269294, -121.9189993 ]), array([  37.34253338, -121.8560387 ]), array([  37.33232358, -121.9103755 ]), array([  37.38685668, -121.9636192 ]), array([  37.32587859, -121.9188215 ]), array([  37.29768928, -121.8784525 ]), array([  37.48465951, -121.9468222 ]), array([  37.35993378, -121.9087751 ]), array([  37.2829627, -122.0488974]), array([  37.29374505, -121.963708  ]), array([  37.31657363, -121.8794308 ]), array([  37.33381633, -121.9431781 ]), array([  37.34139913, -121.9086862 ]), array([  37.52764981, -121.908864  ]), array([  37.5307493, -121.9389116]), array([  37.40847736, -122.0375308 ]), array([  37.50522976, -121.9887654 ]), array([  37.32309258, -121.9366006 ]), array([  37.4130942, -121.999604 ]), array([  37.30798718, -121.9618418 ]), array([  37.37845939, -121.9525992 ]), array([  37.39203059, -122.0209228 ]), array([  37.28665681, -121.9392672 ]), array([  37.36705061, -121.9897427 ]), array([  37.57549811, -121.9318894 ]), array([  37.38744763, -121.8536369 ]), array([  37.51718647, -121.9622862 ]), array([  37.4125315, -122.0226104])]
# [array([  37.59225073, -122.4646367 ]), array([  37.46284671, -122.1925639 ]), array([  37.51880789, -122.2626858 ]), array([  37.59426875, -122.4503066 ]), array([  37.50628927, -122.3621602 ]), array([  37.62201869, -122.4532259 ]), array([  37.42351662, -122.1972638 ]), array([  37.47009286, -122.2801427 ]), array([  37.49704444, -122.3742891 ]), array([  37.56270931, -122.3680035 ]), array([  37.48756067, -122.2087909 ]), array([  37.38018286, -122.1402307 ]), array([  37.37110473, -122.1637395 ]), array([  37.53488675, -122.2521395 ]), array([  37.63210059, -122.4376556 ]), array([  37.437837 , -122.1342862]), array([  37.37880559, -122.1820993 ]), array([  37.42471825, -122.1745606 ]), array([  37.4359055, -122.1791726]), array([  37.53668796, -122.3050381 ]), array([  37.49970879, -122.2774844 ]), array([  37.55045581, -122.3370125 ]), array([  37.56715545, -122.3344443 ]), array([  37.41962087, -122.2118055 ]), array([  37.46357409, -122.2644582 ]), array([  37.54996707, -122.3537488 ]), array([  37.56606134, -122.3633997 ]), array([  37.46851353, -122.241858  ]), array([  37.4784411, -122.2559505]), array([  37.45884341, -122.2446057 ]), array([  37.49504853, -122.2731426 ]), array([  37.5932824, -122.3834956]), array([  37.48704732, -122.275092  ]), array([  37.48399344, -122.2563936 ]), array([  37.39731976, -122.1207989 ]), array([  37.50592238, -122.2730539 ]), array([  37.43452531, -122.1256794 ]), array([  37.43835588, -122.2423011 ]), array([  37.43796537, -122.1271878 ]), array([  37.51814638, -122.3409976 ]), array([  37.49620898, -122.2352099 ]), array([  37.42408103, -122.2010768 ]), array([  37.63829832, -122.4449102 ]), array([  37.4743088, -122.2011654]), array([  37.42066461, -122.1726094 ]), array([  37.52339522, -122.2616224 ]), array([  37.64955231, -122.4979775 ]), array([  37.58328003, -122.4916109 ]), array([  37.47803228, -122.2499237 ]), array([  37.31496122, -122.0491638 ]), array([  37.42334314, -122.1655135 ]), array([  37.46973438, -122.2656103 ]), array([  37.53803979, -122.3736694 ]), array([  37.42365135, -122.1968204 ]), array([  37.48472233, -122.1787292 ]), array([  37.41928828, -122.2121601 ]), array([  37.61627709, -122.4313738 ]), array([  37.39255749, -122.1965544 ]), array([  37.35799769, -122.0461446 ]), array([  37.5222198, -122.2691549]), array([  37.40798995, -122.1103273 ]), array([  37.62614245, -122.4943521 ]), array([  37.57236203, -122.3403777 ]), array([  37.57919701, -122.3765908 ]), array([  37.54315451, -122.3633112 ]), array([  37.40048676, -122.1093511 ]), array([  37.38888538, -122.1459088 ]), array([  37.49359641, -122.261711  ]), array([  37.4177316, -122.1536269]), array([  37.54504524, -122.276687  ]), array([  37.47157706, -122.2774844 ]), array([  37.59336426, -122.3890722 ]), array([  37.44127156, -122.1634734 ]), array([  37.53932983, -122.3142505 ]), array([  37.50537443, -122.3394921 ]), array([  37.50912493, -122.471801  ]), array([  37.50453858, -122.2820034 ]), array([  37.6170941, -122.4372133]), array([  37.48379406, -122.188928  ]), array([  37.53715057, -122.2868765 ]), array([  37.48868507, -122.2272317 ]), array([  37.38448846, -122.1907903 ]), array([  37.42494819, -122.1629412 ]), array([  37.46099963, -122.2549756 ]), array([  37.59272619, -122.3867707 ]), array([  37.5227076, -122.3490558]), array([  37.50888279, -122.4983312 ]), array([  37.54513618, -122.2915722 ]), array([  37.64695933, -122.4872778 ])]
# [array([  37.82390984, -122.3167307 ]), array([  37.77469856, -122.2528485 ]), array([  37.80533759, -122.2998114 ]), array([  37.8212827, -122.3745547]), array([  37.77915282, -122.2828894 ]), array([  37.79261926, -122.2563936 ]), array([  37.76352465, -122.2386669 ]), array([  37.79391326, -122.2748262 ]), array([  37.78337607, -122.362957  ]), array([  37.80340682, -122.2832438 ]), array([  37.82070157, -122.3740235 ]), array([  37.80668692, -122.2705728 ]), array([  37.7473255, -122.2533803]), array([  37.79517944, -122.3921701 ]), array([  37.80528544, -122.2671168 ]), array([  37.78311572, -122.2648127 ]), array([  37.79770874, -122.3885411 ]), array([  37.84838843, -122.3701283 ]), array([  37.79761174, -122.394914  ]), array([  37.80486556, -122.2670282 ]), array([  37.78372842, -122.3000772 ]), array([  37.8317113, -122.3980118]), array([  37.81487071, -122.3564051 ]), array([  37.78614041, -122.3672952 ]), array([  37.77318458, -122.2763325 ]), array([  37.76239045, -122.2709272 ]), array([  37.80907806, -122.3781843 ])]

# %% [markdown]
# ***
# <a/ id='p3'></a>
# [Back to top](#top)
# # Problem 3 (Simulation on the GMM; 15 pts)
#
#
# Because the GMM is a *generative* model, we could use our results from Problem 2 to not only score models based on their mean-distance-to-centroid (or other statistical measures like AIC, BIC), we could simulate points from the models and visually ascertain whether or not they appear similar to the original distribution.
#
# **Part A**:
#
# For each of the GMM models in Problem 2 from $k=[2,3,4,5,6,7,8]$, simulate 1000 points from your estimated density function (recall: this is a two-part simulation of choosing a component **then** drawing from the normal of appropriate mean/covariance).
#
# Create a figure with 2 columns and 4 rows holding all 8 data sets: the 7 simulated ones and the original data shown above.  Label each plot appropriately.

# %%
kMax = 8
kk = [k for k in range(2, kMax+1)]

means = [[] for k in range(kMax - 1)]
covars = [[] for k in range(kMax - 1)]
relFreq = [[] for k in range(kMax - 1)]

for i, k in enumerate(kk):
    totalGMM = GMM(df, k)
    relFreq[i] = totalGMM[3]
    means[i] = totalGMM[1]
    covars[i] = totalGMM[2]
    print(f"Done processing k = {k}")
# Out:
# Done processing k = 2
# Done processing k = 3
# Done processing k = 4
# Done processing k = 5
# Done processing k = 6
# Done processing k = 7
# Done processing k = 8

# %%
test = stats.multivariate_normal.rvs(np.array(means)[0][0], np.array(covars)[0][0])

sample = [[] for i in range(kMax)]
for num, k in enumerate(kk):
    for i in range(1000):
        clustChosen=np.random.choice(k, p=relFreq[num])
        newDat = stats.multivariate_normal.rvs(np.asarray(means)[num][clustChosen], np.asarray(covars)[num][clustChosen])
        sample[num].append(newDat)


fig, ax = plt.subplots(figsize=(15,10), nrows=4, ncols=2)
fig.tight_layout(pad=5.0)
ax[0,0].scatter(df['lat'], df['lng'])
ax[0,0].set_title('Original Data')

row = 0
col = 1
sample.pop()
for num, kPoints in enumerate(sample):
    ax[row,col].scatter(np.asarray(sample[num])[:,0],np.asarray(sample[num])[:,1])
    ax[row,col].set_title(f'k = {num + 2} GMM Sim')

    if((num + 1) % 2 == 1):
        row += 1
        col = 0
    else:
        col = 1

print(test)
# Out:
# /tmp/ipykernel_379/137902143.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   test = stats.multivariate_normal.rvs(np.array(means)[0][0], np.array(covars)[0][0])
# /tmp/ipykernel_379/137902143.py:7: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   newDat = stats.multivariate_normal.rvs(np.asarray(means)[num][clustChosen], np.asarray(covars)[num][clustChosen])
# [  37.79662696 -122.23862282]

# %% [markdown]
# **Part B**:
#
#
# Which plot or plots look closest to the original data?  Depending on your interpretations of the elbow plot versus the simulated data, you may have decided that we wanted a different value of $k$ for the best model to *simulate* from rather than the best model to *cluster* or classify upon.  Do you think that this is normally the case?  Why or why not?  What properties of a data set would make one task easier or harder with more or less $k$?

# %% [markdown]
# It seems as though the value of k and the distrivution are positively correlated in the sense that a higher value of k yields a distribution that more cloesly resembles the original data. This could be a potential case of overfitting since there are approximately 400 data points which are densely populated on this plot. This may lead to a model that can only reform teh data already given rather than prediciting new points.
